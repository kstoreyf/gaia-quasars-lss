# %%
import numpy as np
import healpy as hp
from healpy.newvisufunc import projview
from astropy.table import Table

import matplotlib
from matplotlib import pyplot as plt

import sys
sys.path.insert(0,'../code')
import utils

# %load_ext autoreload
# %autoreload 2

# %%
matplotlib.rcParams['ytick.labelsize'] = 18
matplotlib.rcParams['xtick.labelsize'] = 18
matplotlib.rcParams['axes.labelsize'] = 22
matplotlib.rcParams['legend.fontsize'] = 18

matplotlib.rc('text', usetex=True)

# %%
cmap_map = 'plasma'

# %% [markdown]
# ## Selfuncs

# %%
tag_selfunc = '_dust'
fn_selfunc = f'../data/maps/selection_function_NSIDE64_catwise{tag_selfunc}.fits'
#map_zodi = maps.get_unwise_scan_map(NSIDE, fn_map=fn_unwisescanmap)
map_selfunc = hp.read_map(fn_selfunc)
print(map_selfunc.shape)
print(np.sum(~np.isnan(map_selfunc)))
print(np.sum(map_selfunc==0))
print(map_selfunc)
# Out:
# (49152,)
# 49152
# 15492
# [0.78230168 0.77867881 0.72079718 ... 0.74767978 0.75844951 0.74423579]

# %%
np.min(map_selfunc), np.min(map_selfunc[map_selfunc>0]), np.max(map_selfunc)
# Out:
# (0.0, 0.6386348867563634, 2.029655099354038)

# %%
projview(map_selfunc, title="Selection function, CatWISE, dust",
         unit="completeness", cmap=cmap_map, coord=['C', 'G'], 
         graticule=True, 
         min=0.7, max=0.8,
         #cbar_ticks=[0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        )

# %%
tag_selfunc = '_dustzodis'
fn_selfunc = f'../data/maps/selection_function_NSIDE64_catwise{tag_selfunc}.fits'
#map_zodi = maps.get_unwise_scan_map(NSIDE, fn_map=fn_unwisescanmap)
map_selfunc = hp.read_map(fn_selfunc)
print(map_selfunc.shape)
np.min(map_selfunc), np.min(map_selfunc[map_selfunc>0]), np.max(map_selfunc)
# Out:
# (49152,)

# %%
projview(map_selfunc, title="Selection function, CatWISE, dust+zodi3.4+zodi4.6",
         unit="completeness", cmap=cmap_map, coord=['C', 'G'], 
         graticule=True, 
         min=0.7, max=0.85,
         #cbar_ticks=[0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        )

# %%
tag_selfunc = ''
fn_selfunc = f'../data/maps/selection_function_NSIDE64_catwise{tag_selfunc}.fits'
#map_zodi = maps.get_unwise_scan_map(NSIDE, fn_map=fn_unwisescanmap)
map_selfunc = hp.read_map(fn_selfunc)
print(map_selfunc.shape)
np.min(map_selfunc), np.min(map_selfunc[map_selfunc>0]), np.max(map_selfunc)
# Out:
# (49152,)
# (0.0, 0.5967579335524581, 2.7550797298269343)

# %%
projview(map_selfunc, title="Selection function, CatWISE, dust+unwise+unwisescan",
         unit="completeness", cmap=cmap_map, coord=['C', 'G'], 
         graticule=True, 
         min=0.7, max=0.85,
         #cbar_ticks=[0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        )

# %%
tag_selfunc = '_pluszodis'
fn_selfunc = f'../data/maps/selection_function_NSIDE64_catwise{tag_selfunc}.fits'
#map_zodi = maps.get_unwise_scan_map(NSIDE, fn_map=fn_unwisescanmap)
map_selfunc = hp.read_map(fn_selfunc)
print(map_selfunc.shape)
np.min(map_selfunc), np.min(map_selfunc[map_selfunc>0]), np.max(map_selfunc)
# Out:
# (49152,)
# (0.0, 0.5922964657761209, 2.674235537944742)

# %%
projview(map_selfunc, title="Selection function, CatWISE, dust+unwise+unwisescan+zodi3.4+zodi4.6",
         unit="completeness", cmap=cmap_map, coord=['C', 'G'], 
         graticule=True, 
         min=0.7, max=0.85,
         #cbar_ticks=[0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        )

# %% [markdown]
# # Quaia

# %%
G_lo = 20.0

# %%
tag_selfunc = '_nomcs'
fn_selfunc = f'../data/maps/selection_function_NSIDE64_G{G_lo}{tag_selfunc}.fits'
#map_zodi = maps.get_unwise_scan_map(NSIDE, fn_map=fn_unwisescanmap)
map_selfunc = hp.read_map(fn_selfunc)
print(map_selfunc.shape)
print(np.min(map_selfunc), np.min(map_selfunc[map_selfunc>0]), np.max(map_selfunc))
# Out:
# (49152,)
# 0.0 0.028679929763425264 0.8001214412803476

# %%
projview(map_selfunc, title=f"Selection function, Quaia G{G_lo}, fiducial - MCs",
         unit="completeness", cmap=cmap_map, coord=['C', 'G'], 
         graticule=True, 
         min=0.2, max=0.8,
         #cbar_ticks=[0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        )

# %%
tag_selfunc = '_nounwise'
fn_selfunc = f'../data/maps/selection_function_NSIDE64_G{G_lo}{tag_selfunc}.fits'
#map_zodi = maps.get_unwise_scan_map(NSIDE, fn_map=fn_unwisescanmap)
map_selfunc = hp.read_map(fn_selfunc)
print(map_selfunc.shape)
print(np.min(map_selfunc), np.min(map_selfunc[map_selfunc>0]), np.max(map_selfunc))
# Out:
# (49152,)
# 0.0 0.02739787255879565 0.7630777669315425

# %%
projview(map_selfunc, title=f"Selection function, Quaia G{G_lo}, fiducial - unwise-related",
         unit="completeness", cmap=cmap_map, coord=['C', 'G'], 
         graticule=True, 
         min=0.2, max=0.8,
         #cbar_ticks=[0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        )

# %%
tag_selfunc = ''
fn_selfunc = f'../data/maps/selection_function_NSIDE64_G{G_lo}{tag_selfunc}.fits'
#map_zodi = maps.get_unwise_scan_map(NSIDE, fn_map=fn_unwisescanmap)
map_selfunc = hp.read_map(fn_selfunc)
print(map_selfunc.shape)
print(np.min(map_selfunc), np.min(map_selfunc[map_selfunc>0]), np.max(map_selfunc))
# Out:
# (49152,)
# 0.0 0.02618584620816372 0.7873269787302883

# %%
projview(map_selfunc, title=f"Selection function, Quaia G{G_lo}, fiducial",
         unit="completeness", cmap=cmap_map, coord=['C', 'G'], 
         graticule=True, 
         min=0.2, max=0.8,
         #cbar_ticks=[0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        )

# %%
tag_selfunc = '_pluszodi1.25'
fn_selfunc = f'../data/maps/selection_function_NSIDE64_G{G_lo}{tag_selfunc}.fits'
#map_zodi = maps.get_unwise_scan_map(NSIDE, fn_map=fn_unwisescanmap)
map_selfunc = hp.read_map(fn_selfunc)
print(map_selfunc.shape)
print(np.min(map_selfunc), np.min(map_selfunc[map_selfunc>0]), np.max(map_selfunc))
# Out:
# (49152,)
# 0.0 0.026101040558236855 0.790392661933709

# %%
projview(map_selfunc, title=f"Selection function, Quaia G{G_lo}, + zodi1.25",
         unit="completeness", cmap=cmap_map, coord=['C', 'G'], 
         graticule=True, 
         min=0.2, max=0.8,
         #cbar_ticks=[0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        )

# %%
tag_selfunc = '_pluszodis'
fn_selfunc = f'../data/maps/selection_function_NSIDE64_G{G_lo}{tag_selfunc}.fits'
#map_zodi = maps.get_unwise_scan_map(NSIDE, fn_map=fn_unwisescanmap)
map_selfunc = hp.read_map(fn_selfunc)
print(map_selfunc.shape)
print(np.min(map_selfunc), np.min(map_selfunc[map_selfunc>0]), np.max(map_selfunc))
# Out:
# (49152,)
# 0.0 0.0253657988401908 0.7904227235019086

# %%
projview(map_selfunc, title=f"Selection function, Quaia G{G_lo}, + zodi1.25 + zodi3.4 + zodi4.6",
         unit="completeness", cmap=cmap_map, coord=['C', 'G'], 
         graticule=True, 
         min=0.2, max=0.8,
         #cbar_ticks=[0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        )

# %%
tag_selfunc = '_pluszodi1.25nounwise'
fn_selfunc = f'../data/maps/selection_function_NSIDE64_G{G_lo}{tag_selfunc}.fits'
#map_zodi = maps.get_unwise_scan_map(NSIDE, fn_map=fn_unwisescanmap)
map_selfunc = hp.read_map(fn_selfunc)
print(map_selfunc.shape)
print(np.min(map_selfunc), np.min(map_selfunc[map_selfunc>0]), np.max(map_selfunc))
# Out:
# (49152,)
# 0.0 0.026195586620719323 0.7708453667966351

# %%
projview(map_selfunc, title=f"Selection function, Quaia G{G_lo}, -unwise-related + zodi1.25",
         unit="completeness", cmap=cmap_map, coord=['C', 'G'], 
         graticule=True, 
         min=0.2, max=0.8,
         #cbar_ticks=[0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        )
